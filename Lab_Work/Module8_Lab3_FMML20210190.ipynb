# %% [markdown]
# <a href="https://colab.research.google.com/github/Eshan-Sharma/fmml2021/blob/main/Lab_Work/Module8_Lab3_FMML20210190.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Bayesian Machine Learning: Lab 3 - Applying Bayes Classifiers

# %% [markdown]
# <table class="tfo-notebook-buttons" align="left">
#   <td>
#     <a target="_blank" href="https://colab.research.google.com/drive/1TuDbIyso6irdyBFgaHRpC-PxUICWPHcS?usp=sharing"><img height="32px" src="https://colab.research.google.com/img/colab_favicon.ico" />Run in Google Colab</a>
#   </td>
#   <td>
#     <a target="_blank" href="https://github.com/Foundations-in-Modern-Machine-Learning/course-contents/tree/main/Bayesian/"><img src="https://www.tensorflow.org/images/GitHub-Mark-32px.png" />View source on GitHub</a>
#   </td>
# </table>
# <br>
# <br>
# <br>

# %%
import os
import json
import re

import numpy as np
import pandas as pd

from matplotlib import pyplot as plt
import seaborn as sns
import plotly.express as px
import plotly.graph_objects as pg

import tensorflow as tf
import tensorflow_probability as tfp

# %%
# !wget https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
plt.style.use('ggplot')
# Out:
# --2022-07-08 07:45:38--  https://raw.githubusercontent.com/Foundations-in-Modern-Machine-Learning/course-contents/main/Bayesian/data/arxiv-paper-data.json
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.110.133, 185.199.109.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.110.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 72422946 (69M) [text/plain]
# Saving to: ‘arxiv-paper-data.json’
#
# arxiv-paper-data.js 100%[===================>]  69.07M   163MB/s    in 0.4s
#
# 2022-07-08 07:45:39 (163 MB/s) - ‘arxiv-paper-data.json’ saved [72422946/72422946]

# %% [markdown]
# Let's make a few assumptions to come up with our first general model for classification:
# * The different features contribute equally to the result
# * The features are independent

# %% [markdown]
# ## Bayes Classifiers in Scikit Learn

# %% [markdown]
# ### Simple 1-D Classfication using Naive Bayes in Continuous Space

# %%
fig, ax = plt.subplots(figsize=(18, 8))
x1 = np.random.normal(1.0, 0.3, size=5000)
x2 = np.random.normal(0.0, 0.3, size=50000)
x = np.concatenate([x1, x2])
y = np.concatenate([np.zeros(len(x1)), np.ones(len(x2))])
sns.histplot(x1, color='blue', alpha=0.5, ax=ax)
sns.histplot(x2, color='red', alpha=0.5, ax=ax)
ax.fill_between(np.linspace(-1.0, 0.7, 100), 0, 1800,  color='r', alpha=0.1)
ax.fill_between(np.linspace(0.7, 2.0, 100), 0, 1800,  color='b', alpha=0.1)
ax.vlines(0.5, 0, 1750, color="k", linestyles="--", lw=3)
ax.vlines(0.7, 0, 1750, color="g", linestyles="--", lw=3)
ax.scatter(x1, [np.random.randint(2000, 3000) for _ in x1], color='b', s=1)
ax.scatter(x2, [np.random.randint(2000, 3000) for _ in x2], color='r', s=1)
ax.set_xlim(-1.0, 2.0)
ax.set_ylim(0, 3200)
plt.show()

# %%
from sklearn.naive_bayes import GaussianNB
gnb = GaussianNB()
x_reshaped = x.reshape(1, -1)
print(x_reshaped.shape)
# Out:
# (1, 55000)

# %% [markdown]
# ## Gaussian Bayes Predictor on Predicting Flowers

# %% [markdown]
# ### Predictors in Scikit Learn

# %%
from sklearn.datasets import load_iris
from sklearn.model_selection import train_test_split
from sklearn.naive_bayes import GaussianNB

X, y = load_iris(return_X_y=True)
X = X[:, [2, 3]]
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.5, random_state=0)
gnb = GaussianNB()
gnb.fit(X_train, y_train)
# Out:
# GaussianNB()

# %%
plt.figure(figsize=(20, 10))
color_scheme = ['red', 'green', 'blue']
plt.scatter(X_train[:, 0], X_train[:, 1], c=[color_scheme[idx] for idx in y_train])
plt.show()

# %% [markdown]
# ### Visualizing the Decision Surface

# %%
plt.figure(figsize=(20, 10))
X1_scan, X2_scan = np.meshgrid(np.linspace(0.5, 7.5, 250), np.linspace(0.0, 3.0, 250))
X_scan = np.stack([np.reshape(X1_scan, -1), np.reshape(X2_scan, -1)], axis=-1)
predictions = gnb.predict(X_scan)
color_map = ['r', 'g', 'b']
plt.scatter(x=X_test[:, 0], y=X_test[:, 1], c=[color_map[x] for x in y_test])
sns.kdeplot(x=X_scan[:, 0], y=X_scan[:, 1], hue=[color_map[x] for x in predictions], fill=False)
plt.show()

# %% [markdown]
# ## Bayes on Text - Classifying papers at Arxiv

# %% [markdown]
# ### Data Cleaning and Preprocessing

# %%
arxiv_df = pd.read_json(open("arxiv-paper-data.json", 'r'))
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: json.loads(x.replace("\'", "\"").replace("None", "\"None\""))[0]['term'].split('.')[0])
arxiv_df["tag"] = arxiv_df["tag"].apply(lambda x: 'physics' if x in ['physics', 'quant-ph', 'astro-ph', 'hep-ex', 'hep-ph', 'hep-lat', 'hep-th', 'nucl-th'] else x)
arxiv_df = arxiv_df.drop(["day", "month", "link", "author"], axis=1)

# %%
SAMPLES_COMP = 3500 #@param {type: "slider", min: 1000, max: 4500}
SAMPLES_STAT = 2500 #@param {type: "slider", min: 1000, max: 4500}
WORD_COUNT_THRESHOLD = 1  #@param {type: "slider", min: 1, max: 500}
WORD_LENGTH_THRESHOLD = 8  #@param {type: "slider", min: 4, max: 20}

# %%
df = pd.concat([arxiv_df[arxiv_df['tag'] == 'cs'].sample(SAMPLES_COMP, replace=False), 
                arxiv_df[arxiv_df['tag'] == 'stat'].sample(SAMPLES_STAT, replace=False)]).sample(frac=1)
df['keywords'] = df.apply(lambda x: [word.lower() for word in re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', x.summary + ' ' + x.title)).split() 
                                     if len(word) > WORD_LENGTH_THRESHOLD and not re.search('(\d|\(|\))', word)], axis=1)
train_df, test_df = df.iloc[:int(len(df) * 0.8)], df.iloc[int(len(df) * 0.8):]

train_df
# Out:
#                  id                                            summary   tag  \
# 29249  1708.08844v1  We argue that robust dense SLAM systems can ma...    cs
# 15089   1402.4678v1  We present a new algorithm to model and invest...    cs
# 8204   1612.02297v2  This paper proposes a deep learning architectu...    cs
# 951     1402.1869v2  We study the complexity of functions computabl...  stat
# 11280  1507.02284v3  We introduce a new framework for unsupervised ...  stat
# ...             ...                                                ...   ...
# 29954  1711.02512v1  Image descriptors based on activations of Conv...    cs
# 34883   1209.1734v1  Current autonomic computing systems are ad hoc...    cs
# 34167  1503.04250v1  The YLI Multimedia Event Detection corpus is a...    cs
# 19422   0909.0138v1  Direction relations between extended spatial o...    cs
# 40788   1401.6002v1  Numerous methods exist and were developed for ...  stat
#
#                                                    title  year  \
# 29249         Semantic Texture for Robust Dense Tracking  2017
# 15089  When Learners Surpass their Sources: Mathemati...  2014
# 8204   Spatially Adaptive Computation Time for Residu...  2016
# 951    On the Number of Linear Regions of Deep Neural...  2014
# 11280                              The Information Sieve  2015
# ...                                                  ...   ...
# 29954  Fine-tuning CNN Image Retrieval with No Human ...  2017
# 34883  Load Distribution Composite Design Pattern for...  2012
# 34167  The YLI-MED Corpus: Characteristics, Procedure...  2015
# 19422  Reasoning about Cardinal Directions between Ex...  2009
# 40788  Numerical weather prediction or stochastic mod...  2014
#
#                                                 keywords
# 29249  [alignment, straightforward, formulation, alig...
# 15089  [algorithm, investigate, mastering, grammatica...
# 8204   [architecture, dynamically, architecture, trai...
# 951    [complexity, functions, computable, feedforwar...
# 11280  [introduce, framework, unsupervised, represent...
# ...                                                  ...
# 29954  [descriptors, activations, convolutional, retr...
# 34883  [autonomic, computing, solutions, implemented,...
# 34167  [multimedia, detection, annotations, specializ...
# 19422  [direction, relations, important, commonsense,...
# 40788  [developed, radiation, forecasting, numerical,...
#
# [4800 rows x 6 columns]

# %%
df['keywords']
# Out:
# 29249    [alignment, straightforward, formulation, alig...
# 15089    [algorithm, investigate, mastering, grammatica...
# 8204     [architecture, dynamically, architecture, trai...
# 951      [complexity, functions, computable, feedforwar...
# 11280    [introduce, framework, unsupervised, represent...
#                                ...
# 12853    [demonstrate, minibatch, minibatch, techniques...
# 32805    [reinforcement, proficient, controllers, contr...
# 32330    [applications, involving, identical, distribut...
# 33804    [regression, important, challenging, underlyin...
# 22027    [justifying, represent, arbitrary, independenc...
# Name: keywords, Length: 6000, dtype: object

# %% [markdown]
# ### Learning Probability Distributions

# %%
from collections import defaultdict
dictionary = defaultdict(lambda: [0, 0])
for desc, tag in zip(df['keywords'], df['tag']):
    for word in set(desc):
        if tag == 'cs':
            dictionary[word][0] += 1
        else:
            dictionary[word][1] += 1

print("We have a dictionary of", len(dictionary), "words.")

words, counts_cs, counts_stat = [], [], []
for word, count in dictionary.items():
    if count[0] + count[1] > WORD_COUNT_THRESHOLD:
        words.append(word)
        counts_cs.append(count[0])
        counts_stat.append(count[1])
print("Out of those", len(words), f"have over {WORD_COUNT_THRESHOLD} occurances")

fig = pg.Figure([pg.Bar(x=words[:200], y=counts_cs[:200]), 
                 pg.Bar(x=words[:200], y=counts_stat[:200])])
fig.update_layout(title_text=f'Some random words and the frequency plot of those with over {WORD_COUNT_THRESHOLD} occurances')
fig.show()
# Out:
# We have a dictionary of 8694 words.
# Out of those 4518 have over 1 occurances
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="a4d46620-a3fd-45ae-9eb6-1ed35dee1c5c" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("a4d46620-a3fd-45ae-9eb6-1ed35dee1c5c")) {                    Plotly.newPlot(                        "a4d46620-a3fd-45ae-9eb6-1ed35dee1c5c",                        [{"x":["demonstrate","sequences","resulting","hierarchy","iterations","representation","efficient","experiments","selection","straightforward","variations","performance","alignment","convolutional","formulation","additional","possesses","frequency","constraints","algorithm","compelling","successfully","collected","investigate","virtually","inconsistent","inadequate","possessing","acquisition","singleton","increased","imperfect","mathematical","grammatical","classification","dynamically","detection","positions","efficiency","modifications","deterministic","experimental","additionally","surprisingly","applicable","segmentation","trainable","challenging","computation","therefore","computational","spatially","architecture","correlate","activations","rectifier","activation","regarding","contributes","particular","structure","functions","exponentially","computable","complexity","complicated","piecewise","symmetries","advantage","theoretical","feedforward","investigates","compositional","sequentially","different","progressively","predicting","intuitively","unsupervised","information","independent","representations","including","practical","unexplained","fundamental","compression","maximally","informative","explaining","hierarchical","consisting","implementation","dependence","variables","transformed","component","multivariate","remainder","ultimately","framework","remaining","decomposition","introduce","aggregate","associated","universal","solutions","cognition","reduction","automated","heterogeneous","challenge","dimensional","perspective","conditions","reference","dimension","cognitive","extensive","prediction","substantial","psychological","statistical","neuroscience","available","typically","summarize","mechanism","answering","paragraph","mechanisms","comprehension","interactions","bidirectional","evaluations","attention","attentions","directional","summarization","represents","granularity","temporally","discourse","plausible","correlation","rhetorical","evaluation","knowledge","empirical","precision","considers","processing","documents","explanation","relevance","relations","effectiveness","estimating","semantics","retrieval","modification","radiological","significant","registered","artificial","primarily","anatomical","integration","landmarks","ultrasound","modalities","treatment","specified","differences","researchers","bijective","application","registration","significantly","intensity","evaluated","orientations","multimodal","equipment","clinicians","statistics","preliminary","performing","searching","corresponding","engineered","production","causality","utilizing","pipelines","systematically","streaming","recognition","replacing"],"y":[556,107,136,34,27,340,403,583,156,35,74,892,49,379,75,107,7,67,143,778,15,91,67,151,9,18,3,2,48,2,42,7,52,13,517,27,344,22,151,19,46,386,63,31,48,188,28,269,146,145,306,19,273,10,19,5,35,48,13,285,334,212,16,12,249,40,17,2,95,153,20,27,29,21,737,9,76,13,142,706,114,238,244,138,1,99,46,4,31,14,115,48,136,13,114,31,90,19,1,6,554,28,60,318,12,103,41,148,13,75,94,34,154,159,73,150,58,63,56,181,232,40,10,145,12,286,112,15,123,52,4,55,12,72,25,62,162,5,18,24,50,10,20,19,28,78,3,263,371,147,75,41,275,73,29,34,81,204,84,107,103,20,2,231,5,136,16,10,45,11,4,48,33,28,47,83,2,234,24,283,32,131,12,38,7,3,69,46,74,39,124,9,23,4,42,14,15,14,377,14],"type":"bar"},{"x":["demonstrate","sequences","resulting","hierarchy","iterations","representation","efficient","experiments" ...

# %% [markdown]
# For each word, for both the subjects, we can apply Bayes rule.
#
# $$P\bigg(\frac{\text{subject}}{\text{word}}\bigg) = P\bigg(\frac{\text{word}}{\text{subject}}\bigg) \times \frac{P(\text{subject})}{P(\text{word})}$$

# %% [markdown]
# ### Computing the resultant probabilities

# %%
prior = np.array([train_df["tag"].value_counts()["cs"], train_df["tag"].value_counts()["stat"]]) / len(train_df)
evidence = np.array([counts_cs / train_df["tag"].value_counts()["cs"], counts_stat / train_df["tag"].value_counts()["stat"]]).T
likelihood = (np.array(counts_cs) + np.array(counts_stat)) / len(train_df)

prior.shape, likelihood.shape, evidence.shape
# Out:
# ((2,), (4518,), (4518, 2))

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(
        np.multiply(this_counts.reshape(-1, 1), evidence), likelihood.reshape(-1, 1))) + 0.001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.7941666666666667

# %% [markdown]
# ### Visualizing a few examples

# %%
def explain(example):
    from IPython.display import HTML
    title, desc, answer = example["title"], example["summary"], example["tag"]
    html = ""
    title = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', title)))
    desc = re.sub(' +', ' ', re.sub('[^(\w| )]', '', re.sub('(-|_|\n)', ' ', desc)))
    for text in [title, desc]:
        for word in text.split():
            idx = words_to_index[word.lower()]
            if idx == -1:
                html += f"<span style=''>{word}</span> "
            else:
                posterior = np.multiply(evidence[idx], prior)
                posterior /= np.sum(posterior)
                if posterior[0] > posterior[1] if answer == 'cs' else (posterior[0] <= posterior[1]):
                    color = max(0.3, posterior[0] - posterior[1])
                    html += f"<span style='background-color:rgba(0, 255, 0, {color});'>{word}</span> "
                else:
                    color = max(0.3, posterior[1] - posterior[0])
                    html += f"<span style='background-color:rgba(255, 0, 0, {color});'>{word}</span> "
        html += "<br/><br/>"
    return HTML(html)

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>GPU</span> <span style=''>Based</span> <span style=''>Fuzzy</span> <span style=''>C</span> <span style=''>Means</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithm</span> <span style=''>for</span> <span style=''>Image</span> <span style='background-color:rgba(0, 255, 0, 0.6936936936936937);'>Segmentation</span> <br/><br/><span style=''>In</span> <span style=''>this</span> <span style=''>paper</span> <span style=''>a</span> <span style=''>fast</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>practical</span> <span style=''>GPU</span> <span style=''>based</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>implementation</span> <span style=''>of</span> <span style=''>Fuzzy</span> <span style=''>C</span> <span style=''>Means(FCM)</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>clustering</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style=''>image</span> <span style='background-color:rgba(0, 255, 0, 0.6936936936936937);'>segmentation</span> <span style=''>is</span> <span style=''>proposed</span> <span style=''>First</span> <span style=''>an</span> <span style='background-color:rgba(0, 255, 0, 0.3115942028985507);'>extensive</span> <span style=''>analysis</span> <span style=''>is</span> <span style='background-color:rgba(0, 255, 0, 0.39130434782608703);'>conducted</span> <span style=''>to</span> <span style=''>study</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>dependency</span> <span style=''>among</span> <span style=''>the</span> <span style=''>image</span> <span style=''>pixels</span> <span style=''>in</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithm</span> <span style=''>for</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>parallelization</span> <span style=''>The</span> <span style=''>proposed</span> <span style=''>GPU</span> <span style=''>based</span> <span style=''>FCM</span> <span style=''>has</span> <span style=''>been</span> <span style=''>tested</span> <span style=''>on</span> <span style=''>digital</span> <span style=''>brain</span> <span style='background-color:rgba(255, 0, 0, 0.4139534883720931);'>simulated</span> <span style=''>dataset</span> <span style=''>to</span> <span style=''>segment</span> <span style=''>white</span> <span style=''>matter(WM)</span> <span style=''>gray</span> <span style=''>matter(GM)</span> <span style=''>and</span> <span style=''>cerebrospinal</span> <span style=''>fluid</span> <span style=''>(CSF)</span> <span style=''>soft</span> <span style=''>tissue</span> <span style=''>regions</span> <span style=''>The</span> <span style='background-color:rgba(0, 255, 0, 0.8064516129032259);'>execution</span> <span style=''>time</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>sequential</span> <span style=''>FCM</span> <span style=''>is</span> <span style=''>519</span> <span style=''>seconds</span> <span style=''>for</span> <span style=''>an</span> <span style=''>image</span> <span style=''>dataset</span> <span style=''>with</span> <span style=''>the</span> <span style=''>size</span> <span style=''>of</span> <span style=''>1MB</span> <span style=''>While</span> <span style=''>the</span> <span style=''>proposed</span> <span style=''>GPU</span> <span style=''>based</span> <span style=''>FCM</span> <span style=''>requires</span> <span style=''>only</span> <span style=''>233</span> <span style=''>seconds</span> <span style=''>for</span> <span style=''>the</span> <span style=''>similar</span> <span style=''>size</span> <span style=''>of</span> <span style=''>image</span> <span style=''>dataset</span> <span style=''>An</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>estimated</span> <span style=''>245</span> <span st ...

# %%
x = test_df[np.logical_and(test_df["predictions"] == test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>Prolongation</span> <span style=''>of</span> <span style=''>SMAP</span> <span style=''>to</span> <span style=''>Spatio</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>temporally</span> <span style=''>Seamless</span> <span style=''>Coverage</span> <span style=''>of</span> <span style=''>Continental</span> <span style=''>US</span> <span style=''>Using</span> <span style=''>a</span> <span style=''>Deep</span> <span style=''>Learning</span> <span style=''>Neural</span> <span style=''>Network</span> <br/><br/><span style=''>The</span> <span style=''>Soil</span> <span style=''>Moisture</span> <span style=''>Active</span> <span style=''>Passive</span> <span style=''>(SMAP)</span> <span style=''>mission</span> <span style=''>has</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>delivered</span> <span style=''>valuable</span> <span style=''>sensing</span> <span style=''>of</span> <span style=''>surface</span> <span style=''>soil</span> <span style=''>moisture</span> <span style=''>since</span> <span style=''>2015</span> <span style=''>However</span> <span style=''>it</span> <span style=''>has</span> <span style=''>a</span> <span style=''>short</span> <span style=''>time</span> <span style=''>span</span> <span style=''>and</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>irregular</span> <span style=''>revisit</span> <span style=''>schedule</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>Utilizing</span> <span style=''>a</span> <span style=''>state</span> <span style=''>of</span> <span style=''>the</span> <span style=''>art</span> <span style=''>time</span> <span style=''>series</span> <span style=''>deep</span> <span style=''>learning</span> <span style=''>neural</span> <span style=''>network</span> <span style=''>Long</span> <span style=''>Short</span> <span style=''>Term</span> <span style=''>Memory</span> <span style=''>(LSTM)</span> <span style=''>we</span> <span style=''>created</span> <span style=''>a</span> <span style=''>system</span> <span style=''>that</span> <span style=''>predicts</span> <span style=''>SMAP</span> <span style=''>level</span> <span style=''>3</span> <span style=''>soil</span> <span style=''>moisture</span> <span style=''>data</span> <span style=''>with</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>atmospheric</span> <span style=''>forcing</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulated</span> <span style=''>moisture</span> <span style=''>and</span> <span style=''>static</span> <span style=''>physiographic</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>attributes</span> <span style=''>as</span> <span style=''>inputs</span> <span style=''>The</span> <span style=''>system</span> <span style=''>removes</span> <span style=''>most</span> <span style=''>of</span> <span style=''>the</span> <span style=''>bias</span> <span style=''>with</span> <span style=''>model</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>simulations</span> <span style=''>and</span> <span style=''>improves</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>predicted</span> <span style=''>moisture</span> <span style=''>climatology</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>achieving</span> <span style=''>small</span> <span style=''>test</span> <span style=''>root</span> <span style=''>mean</span> <span style=''>squared</span> <span style=''>error</span> <span style=''>(0035)</span> <span style=''>and</span> <span style=''>high</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>correlation</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>coefficient</span> <span style=''>087</span> <span style=''>for</span> <span style=''>over</span> <span style=''>75</span> <span style=''>of</span> <span style=''>Continental</span> <span style=''>United</span> <span style=''>States</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>including</span> <span style=' ...

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "cs")].iloc[0]
explain(x)
# Out:
# <span style=''>From</span> <span style=''>Cutting</span> <span style=''>Planes</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Algorithms</span> <span style=''>to</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Compression</span> <span style=''>Schemes</span> <span style=''>and</span> <span style=''>Active</span> <span style=''>Learning</span> <br/><br/><span style=''>Cutting</span> <span style=''>plane</span> <span style=''>methods</span> <span style=''>are</span> <span style=''>well</span> <span style=''>studied</span> <span style=''>localization(and</span> <span style=''>optimization)</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>We</span> <span style=''>show</span> <span style=''>that</span> <span style=''>they</span> <span style=''>provide</span> <span style=''>a</span> <span style=''>natural</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>framework</span> <span style=''>to</span> <span style=''>perform</span> <span style=''>machinelearning</span> <span style=''>and</span> <span style=''>not</span> <span style=''>just</span> <span style=''>to</span> <span style=''>solve</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>problems</span> <span style=''>posed</span> <span style=''>by</span> <span style=''>machinelearning</span> <span style=''>in</span> <span style=''>addition</span> <span style=''>to</span> <span style=''>their</span> <span style=''>intended</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>optimization</span> <span style=''>use</span> <span style=''>In</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>particular</span> <span style=''>theyallow</span> <span style=''>one</span> <span style=''>to</span> <span style=''>learn</span> <span style=''>sparse</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>classifiers</span> <span style=''>and</span> <span style=''>provide</span> <span style=''>good</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>compression</span> <span style=''>schemesMoreover</span> <span style=''>we</span> <span style=''>show</span> <span style=''>that</span> <span style=''>very</span> <span style=''>little</span> <span style=''>effort</span> <span style=''>is</span> <span style=''>required</span> <span style=''>to</span> <span style=''>turn</span> <span style=''>them</span> <span style=''>intoeffective</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>methods</span> <span style=''>This</span> <span style=''>last</span> <span style=''>property</span> <span style=''>provides</span> <span style=''>a</span> <span style=''>generic</span> <span style=''>way</span> <span style=''>todesign</span> <span style=''>a</span> <span style=''>whole</span> <span style=''>family</span> <span style=''>of</span> <span style=''>active</span> <span style=''>learning</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>algorithms</span> <span style=''>from</span> <span style=''>existing</span> <span style=''>passivemethods</span> <span style=''>We</span> <span style=''>present</span> <span style='background-color:rgba(255, 0, 0, 0.4572490706319703);'>numerical</span> <span style='background-color:rgba(255, 0, 0, 0.3333333333333333);'>simulations</span> <span style=''>testifying</span> <span style=''>of</span> <span style=''>the</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>relevance</span> <span style=''>ofcutting</span> <span style=''>plane</span> <span style=''>methods</span> <span style=''>for</span> <span style=''>passive</span> <span style=''>and</span> <span style=''>active</span> <span style=''>learning</span> <span style=''>tasks</span> <br/><br/>

# %%
x = test_df[np.logical_and(test_df["predictions"] != test_df["tag"], test_df["tag"] == "stat")].iloc[0]
explain(x)
# Out:
# <span style=''>A</span> <span style=''>Case</span> <span style=''>Study</span> <span style=''>in</span> <span style=''>Text</span> <span style=''>Mining</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>Interpreting</span> <span style=''>Twitter</span> <span style=''>Data</span> <span style=''>From</span> <span style=''>World</span> <span style=''>Cup</span> <span style=''>Tweets</span> <br/><br/><span style=''>Cluster</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>a</span> <span style=''>field</span> <span style=''>of</span> <span style=''>data</span> <span style=''>analysis</span> <span style=''>that</span> <span style=''>extracts</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>underlying</span> <span style=''>patterns</span> <span style=''>in</span> <span style=''>data</span> <span style=''>One</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>application</span> <span style=''>of</span> <span style=''>cluster</span> <span style=''>analysis</span> <span style=''>is</span> <span style=''>in</span> <span style=''>text</span> <span style=''>mining</span> <span style=''>the</span> <span style=''>analysis</span> <span style=''>of</span> <span style=''>large</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collections</span> <span style=''>of</span> <span style=''>text</span> <span style=''>to</span> <span style=''>find</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>similarities</span> <span style=''>between</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>documents</span> <span style=''>We</span> <span style=''>used</span> <span style=''>a</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>collection</span> <span style=''>of</span> <span style=''>about</span> <span style=''>30000</span> <span style=''>tweets</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extracted</span> <span style=''>from</span> <span style=''>Twitter</span> <span style=''>just</span> <span style=''>before</span> <span style=''>the</span> <span style=''>World</span> <span style=''>Cup</span> <span style=''>started</span> <span style=''>A</span> <span style=''>common</span> <span style=''>problem</span> <span style=''>with</span> <span style=''>real</span> <span style=''>world</span> <span style=''>text</span> <span style=''>data</span> <span style=''>is</span> <span style=''>the</span> <span style=''>presence</span> <span style=''>of</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>linguistic</span> <span style=''>noise</span> <span style=''>In</span> <span style=''>our</span> <span style=''>case</span> <span style=''>it</span> <span style=''>would</span> <span style=''>be</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>extraneous</span> <span style=''>tweets</span> <span style=''>that</span> <span style=''>are</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>unrelated</span> <span style=''>to</span> <span style=''>dominant</span> <span style=''>themes</span> <span style=''>To</span> <span style=''>combat</span> <span style=''>this</span> <span style=''>problem</span> <span style=''>we</span> <span style=''>created</span> <span style=''>an</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>that</span> <span style=''>combined</span> <span style=''>the</span> <span style=''>DBSCAN</span> <span style='background-color:rgba(255, 0, 0, 0.3);'>algorithm</span> <span style=''>and</span> <span style=''>a</span> <span style='background-color:rgba(0, 255, 0, 0.3);'>consensus</span> <span style=''>matrix</span> <span style=''>This</span> <span style=''>way</span> <span style=''>we</span> <span style=''>are</span> <span style=''>left</span> <span style=''>with</span> <span style=''>the</span> <span style=''>tweets</span> <span style=''>that</span> <span style=''>are</span> <span style=''>related</span> <span style=''>to</span> <span style=''>those</span> <span style=''>dominant</sp ...

# %% [markdown]
# ### Visualizing the Learnt Words

# %%
print("Some Computer Science words are:")
for word_cs in np.argsort(evidence[:, 0] - evidence[:, 1])[-10:]:
    print(f"\t{words[word_cs]} ({evidence[word_cs, 0]})")
print()
print("Some Statistics words are:")
for word_st in np.argsort(evidence[:, 1] - evidence[:, 0])[-10:]:
    print(f"\t{words[word_st]} ({evidence[word_st, 1]})")
# Out:
# Some Computer Science words are:
# 	processing (0.0971045197740113)
# 	experimental (0.1362994350282486)
# 	segmentation (0.06638418079096045)
# 	information (0.24929378531073446)
# 	architecture (0.09639830508474577)
# 	knowledge (0.13100282485875706)
# 	detection (0.12146892655367232)
# 	different (0.2602401129943503)
# 	convolutional (0.1338276836158192)
# 	recognition (0.13312146892655366)
#
# Some Statistics words are:
# 	stochastic (0.13109756097560976)
# 	variables (0.1402439024390244)
# 	estimation (0.16869918699186992)
# 	theoretical (0.15853658536585366)
# 	statistical (0.15853658536585366)
# 	algorithm (0.3932926829268293)
# 	distribution (0.19461382113821138)
# 	inference (0.20528455284552846)
# 	dimensional (0.19207317073170732)
# 	regression (0.18495934959349594)

# %% [markdown]
# ## Probability Smoothing
#
# Probability smoothing is a language modeling technique that assigns some non-zero probability to events that were unseen in the training data. This has the effect that the probability mass is divided over more events, hence the probability distribution becomes more smooth.

# %% [markdown]
# ### Realizing the Problem

# %%
posterior = np.multiply(np.divide(evidence, np.reshape(likelihood, (-1, 1))), np.reshape(prior, (1, -1)))

fig = pg.Figure([pg.Bar(x=words, y=evidence[:20, 0]), 
                 pg.Bar(x=words, y=posterior[:20, 0])])
fig.update_layout(title_text='Evidence and Posterior for each word')
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script src="https://cdn.plot.ly/plotly-2.8.3.min.js"></script>                <div id="6b0deac1-c2d2-47b8-ade2-8243393ecc3a" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("6b0deac1-c2d2-47b8-ade2-8243393ecc3a")) {                    Plotly.newPlot(                        "6b0deac1-c2d2-47b8-ade2-8243393ecc3a",                        [{"x":["demonstrate","sequences","resulting","hierarchy","iterations","representation","efficient","experiments","selection","straightforward","variations","performance","alignment","convolutional","formulation","additional","possesses","frequency","constraints","algorithm","compelling","successfully","collected","investigate","virtually","inconsistent","inadequate","possessing","acquisition","singleton","increased","imperfect","mathematical","grammatical","classification","dynamically","detection","positions","efficiency","modifications","deterministic","experimental","additionally","surprisingly","applicable","segmentation","trainable","challenging","computation","therefore","computational","spatially","architecture","correlate","activations","rectifier","activation","regarding","contributes","particular","structure","functions","exponentially","computable","complexity","complicated","piecewise","symmetries","advantage","theoretical","feedforward","investigates","compositional","sequentially","different","progressively","predicting","intuitively","unsupervised","information","independent","representations","including","practical","unexplained","fundamental","compression","maximally","informative","explaining","hierarchical","consisting","implementation","dependence","variables","transformed","component","multivariate","remainder","ultimately","framework","remaining","decomposition","introduce","aggregate","associated","universal","solutions","cognition","reduction","automated","heterogeneous","challenge","dimensional","perspective","conditions","reference","dimension","cognitive","extensive","prediction","substantial","psychological","statistical","neuroscience","available","typically","summarize","mechanism","answering","paragraph","mechanisms","comprehension","interactions","bidirectional","evaluations","attention","attentions","directional","summarization","represents","granularity","temporally","discourse","plausible","correlation","rhetorical","evaluation","knowledge","empirical","precision","considers","processing","documents","explanation","relevance","relations","effectiveness","estimating","semantics","retrieval","modification","radiological","significant","registered","artificial","primarily","anatomical","integration","landmarks","ultrasound","modalities","treatment","specified","differences","researchers","bijective","application","registration","significantly","intensity","evaluated","orientations","multimodal","equipment","clinicians","statistics","preliminary","performing","searching","corresponding","engineered","production","causality","utilizing","pipelines","systematically","streaming","recognition","replacing","architectures","versatility","employing","inference","strategies","optimization","deployment","applications","underfitting","modelling","witnessed","efficiently","presented","community","classified","stratification","development","properties","maintaining","partitioning","percentage","modularity","iterative","characteristics","variation","classifiers","communities","stability","distribution","competitive","classifier","stratifying","relationships","computations","protection","perturbations","saturated","successful","protected","limitations","estimates","robustness","biologically","adversarial","numerical","regression","coordinate","iteration","randomized","characterized","experiment","quantization","assumption","literature","sufficient","distributed","quantized", ...

# %%
print("Some words which never appear in Computer Science paper:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_cs) == 0)[0][:20]]))
print("Some words which never appear in Statistics papers:\n\t" + "\n\t".join([words[idx] for idx in np.where(np.array(counts_stat) == 0)[0][:20]]))
# Out:
# Some words which never appear in Computer Science paper:
# 	stratifying
# 	impossibility
# 	regressionclassification
# 	unsettled
# 	covariates
# 	pathologies
# 	distributes
# 	bhattacharyya
# 	rehabilitation
# 	nonlinearly
# 	collapsing
# 	reversing
# 	stagewise
# 	anonymized
# 	anonymization
# 	precautions
# 	invertibility
# 	bernstein
# 	ferromagnetic
# 	cytometry
# Some words which never appear in Statistics papers:
# 	imperfect
# 	grammatical
# 	paragraph
# 	discourse
# 	rhetorical
# 	ultrasound
# 	attentional
# 	visuomotor
# 	subjected
# 	illumination
# 	effecting
# 	mediation
# 	ontologies
# 	commonsense
# 	conflicts
# 	photometric
# 	reprojection
# 	levenshtein
# 	termination
# 	entailment

# %% [markdown]
# Notice the fact that there are cases where the Evidence $P\big(\frac{\text{word}}{\text{subject}}\big) \rightarrow 0$. This is because there are occurances of the given word in the corpus (all the abstract of papers put together) of that subject.
#
# However, this is no way implies that if a word (eg. Employment) never occurs in our training corpus in a Computer Science paper, it will also never occur in a paper in the test set.
#
# Therefore, setting $P(\text{word} | \text{subject}) = 0$ is incorrect, since it will make the posterior $P(\text{subject} | \text{word}) = 0$, even if the corresponding count it 0, we need to come up with a smoother formulation of the Evidence variables.

# %% [markdown]
# ### Laplace Smoothing
#
#
#
# https://towardsdatascience.com/laplace-smoothing-in-na%C3%AFve-bayes-algorithm-9c237a8bdece

# %%
alpha = 0.1
counts_cs, counts_stat = np.array(counts_cs), np.array(counts_stat)
evidence_smooth = np.array([(counts_cs + alpha) / (train_df["tag"].value_counts()["cs"] + alpha * len(words)),
                            (counts_stat + alpha) / (train_df["tag"].value_counts()["stat"] + alpha * len(words))]).T
print(np.min(evidence_smooth))
sns.displot(evidence_smooth)
# Out:
# 3.0452524514282233e-05

# %%
words_to_index = defaultdict(lambda: -1)
for idx, word in enumerate(words):
    words_to_index[word] = idx

correct, total = 0, 0

answers = []
for tag, keywords in zip(test_df["tag"], test_df["keywords"]):
    this_counts = np.zeros(len(words))
    for word in keywords:
        idx = words_to_index[word]
        if idx != -1:
            this_counts[idx] = 1

    marginal = np.multiply(prior.T, np.divide(np.multiply(this_counts.reshape(-1, 1), evidence_smooth), likelihood.reshape(-1, 1))) + 0.0000001
    joint = np.sum(np.log(marginal), axis=0)
    predicted = 'cs' if joint[0] > joint[1] else 'stat'
    answers.append(predicted)
    if predicted == tag:
        correct += 1
    total += 1
test_df.insert(1, "predictions", answers, True)

print("Accuracy:", correct / total)
# Out:
# Accuracy: 0.755
